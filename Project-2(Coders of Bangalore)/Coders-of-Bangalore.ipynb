# %%
with open("initialdata.txt","r")as f:
    data=f.read()
    
chunks=data.split("\n\n")
chunks = [c for c in chunks if len(c)>3]
def parse_chunk(chunk):
    chunk=chunk.strip()
    sep_chunk=chunk.split("\n")
    username=sep_chunk[0]
    no_of_posts=int(sep_chunk[1].split(" post")[0].replace(",", ""))
    no_of_followers=float(sep_chunk[2].split(" followers")[0].replace(",","").replace("K","").replace("M",""))
    if "K" in sep_chunk[2]:
        no_of_followers = int(no_of_followers*1000)
    elif "M" in sep_chunk[2]:
        no_of_followers= int(no_of_followers*1000000)
    else:
        no_of_followers=int(no_of_followers)
        
    no_of_following=float(sep_chunk[3].split(" following")[0].replace(",","").replace("K","").replace("M",""))
    if "K" in sep_chunk[3]:
        no_of_following = int(no_of_following*1000)
    elif "M" in sep_chunk[3]:
        no_of_following= int(no_of_following*1000000)
    else:
        no_of_following=int(no_of_following)
        
    name=sep_chunk[4]
    if (len(sep_chunk) > 5):
        type_of_page=sep_chunk[5]
        bio="\n".join(sep_chunk[6:])
    else:
        type_of_page = "Unknown"
        bio = ""
    # print(sep_chunk)
    return {"username":username, "no_of_post": no_of_posts, "no_of_followers":no_of_followers, "no_of_following":no_of_following, "name":name, "type_of_page":type_of_page, "bio":bio}
    
# parse_chunk(chunks[0])

# %%
all_chunks=[]
for chunk in chunks:
    parsed_chunks=parse_chunk(chunk)
    all_chunks.append(parsed_chunks)
# print(all_chunks)
import json
s=json.dumps(all_chunks, indent=4)
# print(s)

max_posts=max(all_chunks, key=lambda x: x["no_of_post"])
print(max_posts)

max_followers=max(all_chunks, key=lambda x: x["no_of_followers"])
print(max_followers)
# Out:
# {'username': 'startuphub_blr', 'no_of_post': 2300, 'no_of_followers': 45000, 'no_of_following': 120, 'name': 'Startup Hub Bangalore', 'type_of_page': 'Media', 'bio': '🦄 News from the Silicon Valley of India\n📢 Funding alerts, Hiring trends, and Drama\n📩 DM for features\nstartuphub.blr/newsletter'}
# {'username': '_anujsinghal', 'no_of_post': 1785, 'no_of_followers': 681000, 'no_of_following': 248, 'name': 'Anuj Singhal', 'type_of_page': 'Digital creator', 'bio': 'Managing Editor, CNBC-Awaaz. Most trusted and followed biz anchor in India\nLet’s talk about finance and life\nContact: Singhalanuj1010@gmail.com\nhindi.cnbctv18.com/market-gurukul'}

# %%
max=0
for chunk in all_chunks:
    if(max<chunk["no_of_following"]):
        max=chunk["no_of_following"]
        max_following=chunk
print(max_following)
# Out:
# {'username': 'katiasales2220', 'no_of_post': 107, 'no_of_followers': 219, 'no_of_following': 1401, 'name': 'Katia Sales', 'type_of_page': 'Alfabetização e Reforço Escolar', 'bio': 'Ensino Fundamental I e II\nPreparação para Escola Militar\nPortuguês e Matemática\nCursando Psicopedagogia Estácio'}

# %%
categories=set()
for chunk in all_chunks:
    categories.add(chunk["type_of_page"])
print(category, len(categories))
# Out:
# {'Gamer', 'Alfabetização e Reforço Escolar', 'Investor', 'Community', 'Personal Blog', 'Media', 'Unknown', 'Digital creator', 'Entrepreneur', 'Food & Drink', 'Public Figure', 'Nonprofit organization', 'Blogger'} 13
