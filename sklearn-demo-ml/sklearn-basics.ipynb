# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# Features: [weight (grams), color (0 = red, 1 = orange)]
features = [
    [150, 0],  # Apple
    [170, 0],  # Apple
    [130, 1],  # Orange
    [120, 1],  # Orange
]

# %%
labels=["apple", "apple", "orange", "orange"]

# %%
clf=DecisionTreeClassifier()

# %%
clf=clf.fit(features, labels)

# %%
prediction=clf.predict([[170,1], [84,0], [200, 1]])

# %%
prediction
# Out:
# array(['apple', 'orange', 'apple'], dtype='<U6')

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,10))
plot_tree(clf, feature_names=("weight", "color"), class_names=("apple", "orange"), filled=True)
# Out:
# [Text(0.5, 0.75, 'weight <= 140.0\ngini = 0.5\nsamples = 4\nvalue = [2, 2]\nclass = apple'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = orange'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = apple'),
#  Text(0.625, 0.5, '  False')]
