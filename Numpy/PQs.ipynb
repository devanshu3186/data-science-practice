# %% [markdown]
# # Practice Questions

# %% [markdown]
# Q1. Create a 3×3 array filled with random numbers and print its shape.

# %%
import numpy as np

arr=np.array([[2,4,5],[23,4,8],[0,18,1]])
arr.shape
# Out:
# (3, 3)

# %% [markdown]
# Q2. Convert an array of floats [1.1, 2.2, 3.3] into integers.

# %%
arr=np.array([1.1,2.2,3.3])
arr
# Out:
# array([1.1, 2.2, 3.3])

# %%
int_arr=arr.astype(np.int64)
int_arr
# Out:
# array([1, 2, 3])

# %% [markdown]
# Q3. Use fancy indexing to extract even numbers from [1, 2, 3, 4, 5, 6].

# %%
arr=np.array([1,2,3,4,5,6])
print(arr[[1,3,5]])
# Out:
# [2 4 6]

# %% [markdown]
# Q4. Reshape a 1D array of size 9 into a 3×3 matrix.

# %%
arr=np.array([[2,4,5],[23,4,8],[0,18,1]])
arr1=arr.flatten()
print(arr1.size)
print(arr1)
# Out:
# 9
# [ 2  4  5 23  4  8  0 18  1]

# %%
reshaped=arr1.reshape((3,3))
reshaped
# Out:
# array([[ 2,  4,  5],
#        [23,  4,  8],
#        [ 0, 18,  1]])

# %% [markdown]
# Q5. Use boolean masking to filter numbers greater than 50 in an array.

# %%
arr=np.array([[91,4,55],[23,4,80],[0,18,100]])
mask=arr>50
arr[mask]
# Out:
# array([ 91,  55,  80, 100])
