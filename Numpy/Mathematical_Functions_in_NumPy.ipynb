# %%
import numpy as np
arr=np.array([12,34,56,3,21,89,67,2,5,6,99])
# arr=np.array([3,5,2,33])
arr
# Out:
# array([12, 34, 56,  3, 21, 89, 67,  2,  5,  6, 99])

# %%
print(np.mean(arr))
# Out:
# 35.81818181818182

# %%
print(np.std(arr))
# Out:
# 34.44314995049664

# %%
print(np.var(arr))
# Out:
# 1186.3305785123966

# %%
print(np.min(arr))
# Out:
# 2

# %%
print(np.max(arr))
# Out:
# 99

# %%
print(np.sum(arr))
# Out:
# 394

# %%
print(np.prod(arr))
# Out:
# 50984714753280

# %%
print(np.median(arr))
# Out:
# 21.0

# %%
print(np.percentile(arr, 50))
# Out:
# 21.0

# %%
print(np.array)
# Out:
# <built-in function array>
