# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Department": ["HR", "HR", "IT", "IT", "Marketing", "Marketing", "Sales", "Sales"],
    "Team": ["A", "A", "B", "B", "C", "C", "D", "D"],
    "Gender": ["M", "F", "M", "F", "M", "F", "M", "F"],
    "Salary": [85, 90, 78, 85, 92, 88, 75, 80],
    "Age": [23, 25, 30, 22, 28, 26, 21, 27],
    "JoinDate": pd.to_datetime([
        "2020-01-10", "2020-02-15", "2021-03-20", "2021-04-10",
        "2020-05-30", "2020-06-25", "2021-07-15", "2021-08-01"
    ])
})  
df
# Out:
#   Department Team Gender  Salary  Age   JoinDate
# 0         HR    A      M      85   23 2020-01-10
# 1         HR    A      F      90   25 2020-02-15
# 2         IT    B      M      78   30 2021-03-20
# 3         IT    B      F      85   22 2021-04-10
# 4  Marketing    C      M      92   28 2020-05-30
# 5  Marketing    C      F      88   26 2020-06-25
# 6      Sales    D      M      75   21 2021-07-15
# 7      Sales    D      F      80   27 2021-08-01

# %%
df.groupby("Department")["Salary"].mean()  #Group by Department, then calculate average Salary for each group.
# Out:
# Department
# HR           87.5
# IT           81.5
# Marketing    90.0
# Sales        77.5
# Name: Salary, dtype: float64

# %%
df.groupby("Team")["Salary"].sum()
# Out:
# Team
# A    175
# B    163
# C    180
# D    155
# Name: Salary, dtype: int64

# %%
df.groupby("Team")["Salary"].count()
# Out:
# Team
# A    2
# B    2
# C    2
# D    2
# Name: Salary, dtype: int64

# %%
df.groupby("Team")["Salary"].size()
# Out:
# Team
# A    2
# B    2
# C    2
# D    2
# Name: Salary, dtype: int64

# %%
df.groupby("Team")["Salary"].min()
# Out:
# Team
# A    85
# B    78
# C    88
# D    75
# Name: Salary, dtype: int64

# %%
df.groupby("Team")["Salary"].max()
# Out:
# Team
# A    90
# B    85
# C    92
# D    80
# Name: Salary, dtype: int64

# %%
df.groupby(["Team", "Gender"])["Salary"].mean()
# Out:
# Team  Gender
# A     F         90.0
#       M         85.0
# B     F         85.0
#       M         78.0
# C     F         88.0
#       M         92.0
# D     F         80.0
#       M         75.0
# Name: Salary, dtype: float64

# %%
df.groupby("Department")["Salary"].aggregate(["mean", "max", "min"])
# Out:
#             mean  max  min
# Department
# HR          87.5   90   85
# IT          81.5   85   78
# Marketing   90.0   92   88
# Sales       77.5   80   75

# %%
df.groupby("Department")["Salary"].agg(avg_salary="mean", max_salary="max", min_salary="min")
# Out:
#             avg_salary  max_salary  min_salary
# Department
# HR                87.5          90          85
# IT                81.5          85          78
# Marketing         90.0          92          88
# Sales             77.5          80          75

# %%
df.groupby("Team").agg({
    "Salary": "mean",
    "Age": "max"
})
# Out:
#       Salary  Age
# Team
# A       87.5   25
# B       81.5   30
# C       90.0   28
# D       77.5   27

# %%
df["Avg_Salary"] = df.groupby(["Team"])["Salary"].transform("mean")
df
# Out:
#   Department Team Gender  Salary  Age   JoinDate  Avg_Salary
# 0         HR    A      M      85   23 2020-01-10        87.5
# 1         HR    A      F      90   25 2020-02-15        87.5
# 2         IT    B      M      78   30 2021-03-20        81.5
# 3         IT    B      F      85   22 2021-04-10        81.5
# 4  Marketing    C      M      92   28 2020-05-30        90.0
# 5  Marketing    C      F      88   26 2020-06-25        90.0
# 6      Sales    D      M      75   21 2021-07-15        77.5
# 7      Sales    D      F      80   27 2021-08-01        77.5

# %%
df.groupby("Team").filter(lambda x: x["Salary"].mean() > 85)
# Out:
#   Department Team Gender  Salary  Age   JoinDate  Avg_Salary
# 0         HR    A      M      85   23 2020-01-10        87.5
# 1         HR    A      F      90   25 2020-02-15        87.5
# 4  Marketing    C      M      92   28 2020-05-30        90.0
# 5  Marketing    C      F      88   26 2020-06-25        90.0
