# %%
import pandas as pd
s1=pd.Series([12,45,68,54,33,78,88,91])
s1
# Out:
# 0    12
# 1    45
# 2    68
# 3    54
# 4    33
# 5    78
# 6    88
# 7    91
# dtype: int64

# %%
s2=pd.Series([12,45,68,54,33,78,88,91], index=["a","b","c","d","e","f","g","h"])
s2
# Out:
# a    12
# b    45
# c    68
# d    54
# e    33
# f    78
# g    88
# h    91
# dtype: int64

# %%
print(s1[1])
print(s2["a"])
# Out:
# 45
# 12

# %%
data = {
    "name": ["Alice", "Bob", "Charlie"],
    "age": [25, 30, 35],
    "city": ["Delhi", "Mumbai", "Bangalore"]
}

df = pd.DataFrame(data)   #Creating DataFrame with dictionary of lists.
print(df)
# Out:
#       name  age       city
# 0    Alice   25      Delhi
# 1      Bob   30     Mumbai
# 2  Charlie   35  Bangalore

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
df.index=[1,2,3]

# %%
df
# Out:
#       name  age       city
# 1    Alice   25      Delhi
# 2      Bob   30     Mumbai
# 3  Charlie   35  Bangalore

# %%
df.columns=["Name","Age","City"]

# %%
df
# Out:
#       Name  Age       City
# 1    Alice   25      Delhi
# 2      Bob   30     Mumbai
# 3  Charlie   35  Bangalore
